# %%
# 리스트로 만들고 정렬 1:1로 맞아떨어진다...?
words = ['eat', 'tea', 'tan', 'ate', 'nat', 'bat']

# %%
#[[eat,tea,ate],[tan,nat],[bat]]

# %%
리스트로 만들고 그 값으로 set 만들어서 동일한지 보시

# %%
set_list = []
for word in words:
    set_list.append(tuple(sorted(list(word))))

vs_list = list(set(set_list))

# %%
for word in words:
    for 
    if tuple(word) == vs_list:
# Out:
# [('a', 'e', 't'), ('a', 'n', 't'), ('a', 'b', 't')]

# %%
if 정렬된 값 == 값:
    값이 있는 리스트.append(단어)
elif 값
